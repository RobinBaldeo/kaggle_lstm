# %%
import polars as pl
import spacy
import torch
from collections import namedtuple
from preprocess import load_data
from transformers import  AutoTokenizer
import joblib, pdb, itertools
from functools import partial
from torch.utils.data import Dataset, DataLoader
from torchcrf import CRF
import numpy as np
import torch, os
import torch.nn as nn
from transformers import BertModel
from torch.optim import AdamW

# %%
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
cuda_available = torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device( "cpu")
print(device)
# Out:
# cuda

# %%
# args
model_directory = "C:/Users/prl90/PycharmProjects/kaggle_lstm/bert_tiny/"
stride = 20
max_length  = 450
test_path = 'C:/Users/prl90/PycharmProjects/kaggle_lstm/data/train.json'


fetch_size = 6807

# fetch_size = 10
train_size = int(fetch_size * .8)
validation = int(fetch_size * .2)

hidden_dim = 300
  
max_epochs = 20




tokenizer = AutoTokenizer.from_pretrained(model_directory, device="cuda")


pii_tags = {0:  '<PAD>',
            1: 'O',
             2: 'I-URL_PERSONAL',
             3: 'B-USERNAME',
             4: 'B-NAME_STUDENT',
             5: 'B-STREET_ADDRESS',
             6: 'B-ID_NUM',
             7: 'B-EMAIL',
             8: 'B-URL_PERSONAL',
             9: 'I-PHONE_NUM',
             10: 'B-PHONE_NUM',
             11: 'I-NAME_STUDENT',
             12: 'I-STREET_ADDRESS',
             13: 'I-ID_NUM'}

reverser_pii = {j: i for i, j in pii_tags.items()}


num_labels = len(reverser_pii)

# %%
print(train_size)
print(validation)
# Out:
# 5445
# 1361

# %%
num_labels
# Out:
# 14

# %%
def load_data(file_path, train=True):
    df = pl.read_json(file_path).lazy()
    reshaped_df = (
        df
        .with_columns(
            token_keys=pl.col('tokens')
            .map_elements(lambda f: [i for i in range(len(f))]),
        )
        .explode(['tokens', 'trailing_whitespace', 'token_keys'])
        .with_columns(
            token_len=pl.col('tokens').str.len_chars(),
        )
        .with_columns(
            token_len=pl.struct(['token_keys', 'token_len'])
            .map_elements(lambda f: [f['token_keys']] * f['token_len'])
        )
        .with_columns(
            token_len=pl.when(pl.col('trailing_whitespace') == True)
            .then(pl.col('token_len').list.concat(-1))
            .otherwise(pl.col('token_len')),
            tokens_rec=pl.when(pl.col('trailing_whitespace') == True)
            .then(pl.col('tokens').add(' '))
            .otherwise(pl.col('tokens'))
        )
        .group_by('document', maintain_order=True)
        .agg(
            tokens=pl.col('tokens'),
            token_key=pl.col('token_len').flatten(),
            tokens_rec=pl.col('tokens_rec')
        )
        .with_columns(
            token_rec=pl.col('tokens_rec')
            .list.join(separator='')
        )
        .drop('tokens_rec')
    )
    if train:
        temp = ((reshaped_df
                 .join(df.select(['document', 'labels'])
                       , on='document')
                 )
        )
    else:
        temp = reshaped_df
    return temp

# %%
def tokenize( a, b, tokenizer=tokenizer,stride = stride, max_length = max_length):
    txt = a.to_list()
    doc = b.to_list()

    inputs = tokenizer(txt , 
                       return_tensors="pt", 
                       padding=True, 
                       truncation=True, 
                       return_offsets_mapping=True, 
                       return_overflowing_tokens = True,
                       stride = stride,
                       add_special_tokens=False,
                       max_length= max_length,
                       
                      )

    overflow_to_sample_mapping = inputs["overflow_to_sample_mapping"]
    
    doc_key = []
    for i, mapping in enumerate(overflow_to_sample_mapping):
        doc_key.append(doc[mapping])
    
    offset = inputs['offset_mapping'].tolist()
    print(len(offset))
    attention_mask = inputs['attention_mask'].tolist()
    input_ids = inputs['input_ids'].tolist()
    txt_lst = []
    
    for token_ids in input_ids:
        tokens = tokenizer.convert_ids_to_tokens(token_ids)  
        txt_lst.append(tokens)
        
    return {'txt':txt_lst, 
            'attention_mask': attention_mask, 
            'input_ids':input_ids, 
            'offset': offset ,
            'doc': doc_key
           }

# %%
    
def align_lables(row):
    lbl = row['labels']
    offset = row['offset']
    tok_key = row['token_key']
    token_rec = row['token_rec']
    
    temp_list = []
    for start, end in offset:
        if (start== 0 and end ==0):
            temp_list.append('<PAD>')
            continue
        if token_rec[start].isspace():
            start +=1
        temp = tok_key[start]
            
        temp_list.append(lbl[temp])
    return temp_list

# %%
# %%time


load_df = load_data(test_path, train = True).fetch(fetch_size)
vali_  = load_df.tail(validation)
train_ = load_df.head(train_size)
test = load_df.drop('labels')
# Out:
# CPU times: total: 1min 18s
# Wall time: 1min 49s

# %%
# pl.read_json(test_path).shape

# %%
train_
# Out:
# shape: (5_445, 5)
# ┌──────────┬───────────────────────────────┬────────────────┬─────────────────────────────────────┬────────────────────┐
# │ document ┆ tokens                        ┆ token_key      ┆ token_rec                           ┆ labels             │
# │ ---      ┆ ---                           ┆ ---            ┆ ---                                 ┆ ---                │
# │ i64      ┆ list[str]                     ┆ list[i64]      ┆ str                                 ┆ list[str]          │
# ╞══════════╪═══════════════════════════════╪════════════════╪═════════════════════════════════════╪════════════════════╡
# │ 7        ┆ ["Design", "Thinking", … "    ┆ [0, 0, … 752]  ┆ Design Thinking for innovation r…   ┆ ["O", "O", … "O"]  │
# │          ┆                               ┆                ┆                                     ┆                    │
# ...

# %%
# train_['token_rec'].to_list()

# %%
# (pl.LazyFrame(tokenize( train_['token_rec'], train_['document']))
#  .collect()
# )

# %%
vali_
# Out:
# shape: (1_361, 5)
# ┌──────────┬────────────────────────────────┬───────────────┬───────────────────────────────────┬───────────────────┐
# │ document ┆ tokens                         ┆ token_key     ┆ token_rec                         ┆ labels            │
# │ ---      ┆ ---                            ┆ ---           ┆ ---                               ┆ ---               │
# │ i64      ┆ list[str]                      ┆ list[i64]     ┆ str                               ┆ list[str]         │
# ╞══════════╪════════════════════════════════╪═══════════════╪═══════════════════════════════════╪═══════════════════╡
# │ 19704    ┆ ["Learning", "Launch", … "     ┆ [0, 0, … 829] ┆ Learning Launch – Location Ident… ┆ ["O", "O", … "O"] │
# │          ┆                                ┆               ┆                                   ┆                   │
# │          ┆ "]                             ┆               ┆                                   ┆                   │
# ...

# %%
test
# Out:
# shape: (6_807, 4)
# ┌──────────┬──────────────────────────────┬────────────────┬───────────────────────────────────┐
# │ document ┆ tokens                       ┆ token_key      ┆ token_rec                         │
# │ ---      ┆ ---                          ┆ ---            ┆ ---                               │
# │ i64      ┆ list[str]                    ┆ list[i64]      ┆ str                               │
# ╞══════════╪══════════════════════════════╪════════════════╪═══════════════════════════════════╡
# │ 7        ┆ ["Design", "Thinking", … "   ┆ [0, 0, … 752]  ┆ Design Thinking for innovation r… │
# │          ┆                              ┆                ┆                                   │
# │          ┆ "]                           ┆                ┆                                   │
# │ 10       ┆ ["Diego", "Estrada", … "     ┆ [0, 0, … 562]  ┆ Diego Estrada                     │
# ...

# %%
def train_lbl(df):
    return (df.join(
                (
                    
                (pl.LazyFrame(tokenize( df['token_rec'], df['document']))
                 .collect()
                )
                .rename({'doc': 'document'})),on = 'document'
               )
                .with_columns(
                    align_labels = pl.struct(['labels', 'offset', 'token_key', 'token_rec'])
                                     .map_elements(lambda f: align_lables(f))
                )
               .lazy()
              )

# %%
def test_lbl(df):
    return  (df.join(
                (
                    
                (pl.LazyFrame(tokenize( df['token_rec'], df['document']))
                 .collect()
                )
                .rename({'doc': 'document'})),on = 'document'
               )
               .lazy()
              )

# %%
train = train_lbl(train_)
# Out:
# 11532

# %%
valid = train_lbl(vali_)
# Out:
# 2765

# %%
test = test_lbl(test)
# Out:
# 14298

# %%
# train = train[11117: ]

# %%
#  tt = (train[11117: ]
# .collect()
# .with_columns(
#     pl = pl.col('align_labels').map_elements(lambda f: [reverser_pii.get(i) for i in f])
# )
# )

# tt
# print(reverser_pii)

# print(tt[:, 'align_labels'].explode().unique())

# %%
#verification of alignement

# %%
(train
 .with_columns(
     sanity = pl.col('txt').list.len()
                .eq(pl.col('align_labels').list.len())
#                 .eq(pl.col('attention_mask').list.len())
 )
 .drop(['tokens','token_key','token_rec'])
 .explode(['txt', 'align_labels'])
 .filter(pl.col('document').is_in([7,10]))
 .filter(~pl.col('align_labels').is_in(['<PAD>', 'O']) )
 .collect()
)
# Out:
# shape: (21, 8)
# ┌──────────┬──────────────────┬─────────┬────────────────┬─────────────────┬─────────────────┬────────────────┬────────┐
# │ document ┆ labels           ┆ txt     ┆ attention_mask ┆ input_ids       ┆ offset          ┆ align_labels   ┆ sanity │
# │ ---      ┆ ---              ┆ ---     ┆ ---            ┆ ---             ┆ ---             ┆ ---            ┆ ---    │
# │ i64      ┆ list[str]        ┆ str     ┆ list[i64]      ┆ list[i64]       ┆ list[list[i64]] ┆ str            ┆ bool   │
# ╞══════════╪══════════════════╪═════════╪════════════════╪═════════════════╪═════════════════╪════════════════╪════════╡
# │ 7        ┆ ["O", "O", …     ┆ nat     ┆ [1, 1, … 1]    ┆ [2640, 3241, …  ┆ [[0, 6], [7,    ┆ B-NAME_STUDENT ┆ true   │
# │          ┆ "O"]             ┆         ┆                ┆ 1013]           ┆ 15], … [2171,   ┆                ┆        │
# ...

# %%
(train
 .explode(['tokens', 'labels'])
 .filter(pl.col('document').is_in([7,10]))
 .filter(~pl.col('labels').is_in(['O']) )
 .collect()
)
# Out:
# shape: (20, 10)
# ┌──────────┬──────────┬───────────┬────────────────┬───┬───────────────┬───────────────┬───────────────┬───────────────┐
# │ document ┆ tokens   ┆ token_key ┆ token_rec      ┆ … ┆ attention_mas ┆ input_ids     ┆ offset        ┆ align_labels  │
# │ ---      ┆ ---      ┆ ---       ┆ ---            ┆   ┆ k             ┆ ---           ┆ ---           ┆ ---           │
# │ i64      ┆ str      ┆ list[i64] ┆ str            ┆   ┆ ---           ┆ list[i64]     ┆ list[list[i64 ┆ list[str]     │
# │          ┆          ┆           ┆                ┆   ┆ list[i64]     ┆               ┆ ]]            ┆               │
# ╞══════════╪══════════╪═══════════╪════════════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 7        ┆ Nathalie ┆ [0, 0, …  ┆ Design         ┆ … ┆ [1, 1, … 1]   ┆ [2640, 3241,  ┆ [[0, 6], [7,  ┆ ["O", "O", …  │
# ...

# %%
class PIIDataset(Dataset):
    def __init__(self, data, label_to_idx= None):
        
        self.label_to_idx = label_to_idx #reverse lables in the dict is used
        self.data = data

        
    def __len__(self):
        return self.data.shape[0]
    
    def __getitem__(self, idx):
        input_tensors = torch.tensor(self.data[idx, 'input_ids'].to_numpy(), dtype=torch.long)
        attention_tensors = torch.tensor(self.data[idx, 'attention_mask'].to_numpy(), dtype=torch.long)
#         print(idx)
#         print(attention_tensors.shape)
#         print(input_tensors.shape)
        if self.label_to_idx is not None:
            labels_tensor = torch.tensor(self.data[idx, 'align_labels']
                                         .map_elements(lambda f: self.label_to_idx.get(f, 0)).to_numpy()
                                        , dtype=torch.long)
#             print(labels_tensor.shape)
            
            return input_tensors, attention_tensors, labels_tensor
            
        return input_tensors, attention_tensors

# %%
#testing dataclass

# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
dataset = PIIDataset(data=train.collect(), label_to_idx=reverser_pii)


def test_dataloader_integration():
    dataloader = DataLoader(dataset, batch_size=16)
    for inputs, masks,l in dataloader:
        assert torch.is_tensor(inputs), "input_ids should be a tensor."
        assert torch.is_tensor(masks ), "attention_mask should be a tensor."

test_dataloader_integration()

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):

        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss < self.best_loss - self.delta:
            self.save_checkpoint(val_loss, model)
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True

    def save_checkpoint(self, val_loss, model):

        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model to {self.path}')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss
        self.best_loss = val_loss

    def load_checkpoint(self, model):
        model.load_state_dict(torch.load(self.path))
        return model

# %%
# class TinyBertBiLSTMCrf(nn.Module):
#     def __init__(self, bert_model_name, hidden_dim, num_labels, dropout=0.3):
#         super(TinyBertBiLSTMCrf, self).__init__()
#         self.num_labels = num_labels
#         self.bert = BertModel.from_pretrained(bert_model_name)
        
#         self.dropout = nn.Dropout(dropout)
        
#         self.lstm = nn.LSTM(self.bert.config.hidden_size, hidden_dim // 2,
#                             num_layers=1, bidirectional=True, batch_first=True)
#         self.hidden2tag = nn.Linear(hidden_dim, num_labels)
#         self.crf = CRF(num_labels, batch_first=True)

#     def forward(self, input_ids, attention_mask, labels=None):
#         outputs = self.bert(input_ids, attention_mask=attention_mask)
#         sequence_output = self.dropout(outputs.last_hidden_state)
#         lstm_out, _ = self.lstm(sequence_output)
#         emissions = self.hidden2tag(lstm_out)
#         if labels is not None:
#             loss = -self.crf(emissions, labels, mask=attention_mask.byte(), reduction='mean')
#             return loss
#         else:
#             prediction = self.crf.decode(emissions, mask=attention_mask.byte())
#             return prediction

class TinyBertBiLSTMCrf(nn.Module):
    def __init__(self, bert_model_name, hidden_dim, num_labels, dropout=0.3):
        super(TinyBertBiLSTMCrf, self).__init__()
        self.num_labels = num_labels
        self.bert = BertModel.from_pretrained(bert_model_name)
        self.dropout = nn.Dropout(dropout)
        self.lstm = nn.LSTM(self.bert.config.hidden_size, hidden_dim // 2,
                            num_layers=1, bidirectional=True, batch_first=True)
        self.hidden2tag = nn.Linear(hidden_dim, num_labels)
        self.crf = CRF(num_labels, batch_first=True)
        
    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.bert(input_ids, attention_mask=attention_mask)
        sequence_output = self.dropout(outputs.last_hidden_state)

        
        if torch.isnan(sequence_output).any() or torch.isinf(sequence_output).any():
            print("Warning: Found NaN or infinite values in sequence_output.")
            sequence_output = torch.clamp(sequence_output, min=-1e10, max=1e10)

        lstm_out, _ = self.lstm(sequence_output)
        emissions = self.hidden2tag(lstm_out)

        
        if torch.isnan(emissions).any() or torch.isinf(emissions).any():
            print("Warning: Found NaN or infinite values in emissions.")
            emissions = torch.clamp(emissions, min=-1e10, max=1e10)

        print("Emissions shape:", emissions.shape)
        print("Emissions device:", emissions.device)

        if labels is not None:
            print("Labels shape:", labels.shape)
            print("Labels device:", labels.device)
            print("Attention Mask device:", attention_mask.device)

            
            if labels.shape[1] != emissions.shape[1]:
                raise ValueError("Labels sequence length does not match emissions sequence length.")

            
            attention_mask = attention_mask.byte()

            
            if labels.max() >= self.num_labels or labels.min() < 0:
                print(labels)
                print(torch.unique(labels))
                raise ValueError("Invalid tag indices in labels.")

            # Ensure all tensors are on the same device
            if emissions.device != labels.device or emissions.device != attention_mask.device:
                raise ValueError("Input tensors are not on the same device.")

            loss = -self.crf(emissions, labels, mask=attention_mask, reduction='mean')
            return loss
        else:
            
            attention_mask = attention_mask.byte()

            
            if emissions.device != attention_mask.device:
                raise ValueError("Input tensors are not on the same device.")

            prediction = self.crf.decode(emissions, mask=attention_mask)
            return prediction

# %%
train_ds = PIIDataset(data=train.collect(), label_to_idx=reverser_pii)
val_ds = PIIDataset(data=valid.collect(), label_to_idx=reverser_pii)
test_ds = PIIDataset(data=test.collect())
sanity_check = PIIDataset(data=train.collect(), label_to_idx=reverser_pii)


train_loader= DataLoader(train_ds, batch_size=16)
sanity_loader = DataLoader(sanity_check, batch_size=16)
val_loader = DataLoader(val_ds, batch_size=16)
test_loader = DataLoader(test_ds, batch_size=16)

# %%
device
# Out:
# device(type='cuda')

# %%
model = TinyBertBiLSTMCrf(bert_model_name=model_directory,
                          hidden_dim=hidden_dim,
                          num_labels=num_labels)

optimizer = AdamW(model.parameters(), lr=5e-5)


early_stopping = EarlyStopping(patience=7, verbose=True, delta=0.001, path='best_model_checkpoint.pt')


model.to(device)

# Training Loop
for epoch in range(max_epochs):
    model.train()
    train_loss = 0
    for batch in train_loader:

        input_ids, attention_mask, labels = (b.to(device) for b in batch)

        loss = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)


        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()


    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            input_ids, attention_mask, labels = (b.to(device) for b in batch)
            
            
            loss = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            val_loss += loss.item()


    early_stopping(val_loss, model)
    if early_stopping.early_stop:
        print("Early stopping triggered.")
        break
# Out:
# C:\Users\prl90\anaconda3\Lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# C:\Users\prl90\anaconda3\Lib\site-packages\torchcrf\__init__.py:249: UserWarning: where received a uint8 condition tensor. This behavior is deprecated and will be removed in a future version of PyTorch. Use a boolean condition instead. (Triggered internally at ..\aten\src\ATen\native\TensorCompare.cpp:493.)
#   score = torch.where(mask[i].unsqueeze(1), next_score, score)
# Emissions shape: torch.Size([16, 450, 14])
# ...

# %%
model.load_state_dict(torch.load('best_model_checkpoint.pt'))
model.eval()
test_loss = 0
with torch.no_grad():
    for batch in sanity_loader:
        
        input_ids, attention_mask, labels = (b.to(device) for b in batch)

        loss = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        test_loss += loss.item()


print(f"Test Loss: {test_loss}")
# Out:
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# Emissions shape: torch.Size([16, 450, 14])
# Emissions device: cuda:0
# Labels shape: torch.Size([16, 450])
# Labels device: cuda:0
# Attention Mask device: cuda:0
# ...

# %%
import torch


predictions = []
with torch.no_grad():
    for batch in test_loader:
        input_ids, attention_mask = (b.to(device) for b in batch[:2])  # Assuming no labels for prediction
        
        prediction = model(input_ids=input_ids, attention_mask=attention_mask)
        predictions.extend(prediction)

# %%
# set(list(itertools.chain(*predictions)))
